# %% [markdown]
# ![header.png](data:image/png;base64,...)

# %% [markdown]
# # Laboratorio #7 TDSIII
# # Laboratorio Regresion lineal, Regularizacion, inferencia y regresion Bayesiana
# ## Juan Camilo Chaparro Castellanos | Sebastian Escobar Osorio
# ## CC 1039466438 | CC 1017231742

# %%
import numpy as np
import pandas as pd
import scipy as sp
import sklearn as skl

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from ipywidgets import interact
# %matplotlib inline


def normalizar(x):
  nMax = np.max(x)
  nMin = np.min(x)
  norm = []
  for i in x:
    z = (i-nMin)/(nMax-nMin)
    norm.append(z)
  return norm

# %% [markdown]
# ## 1. Base de datos y visualizar oil temperature

# %% [markdown]
# #### Procedemos a realizar la descargar el csv denominado "ETTh1" del repositorio : https://github.com/zhouhaoyi/ETDataset

# %%
# !wget 'https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv'
# Out:
# --2024-11-10 22:25:24--  https://raw.githubusercontent.com/zhouhaoyi/ETDataset/main/ETT-small/ETTh1.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 2606:50c0:8001::154, 2606:50c0:8000::154, 2606:50c0:8003::154, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|2606:50c0:8001::154|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2589657 (2.5M) [text/plain]
# Saving to: 'ETTh1.csv'
#
# ETTh1.csv           100%[===================>]   2.47M  2.24MB/s    in 1.1s
#
# 2024-11-10 22:25:26 (2.24 MB/s) - 'ETTh1.csv' saved [2589657/2589657]

# %% [markdown]
# #### Procedemos a realizar lectura del archivo y normalizar los datos para poder realizar un posterior analisis

# %%
dataframe = pd.read_csv('./ETTh1.csv')
dataframe
# Out:
#                       date    HUFL   HULL   MUFL   MULL   LUFL   LULL  \
# 0      2016-07-01 00:00:00   5.827  2.009  1.599  0.462  4.203  1.340
# 1      2016-07-01 01:00:00   5.693  2.076  1.492  0.426  4.142  1.371
# 2      2016-07-01 02:00:00   5.157  1.741  1.279  0.355  3.777  1.218
# 3      2016-07-01 03:00:00   5.090  1.942  1.279  0.391  3.807  1.279
# 4      2016-07-01 04:00:00   5.358  1.942  1.492  0.462  3.868  1.279
# ...                    ...     ...    ...    ...    ...    ...    ...
# 17415  2018-06-26 15:00:00  -1.674  3.550 -5.615  2.132  3.472  1.523
# 17416  2018-06-26 16:00:00  -5.492  4.287 -9.132  2.274  3.533  1.675
# 17417  2018-06-26 17:00:00   2.813  3.818 -0.817  2.097  3.716  1.523
# 17418  2018-06-26 18:00:00   9.243  3.818  5.472  2.097  3.655  1.432
# 17419  2018-06-26 19:00:00  10.114  3.550  6.183  1.564  3.716  1.462
#
#               OT
# 0      30.531000
# 1      27.787001
# 2      27.787001
# 3      25.044001
# 4      21.948000
# ...          ...
# 17415  10.904000
# 17416  11.044000
# 17417  10.271000
# 17418   9.778000
# 17419   9.567000
#
# [17420 rows x 8 columns]

# %%
valores= dataframe['OT'].values
dias = dataframe['date'].values
X = np.arange(0, 10000)
Y = valores[0:10000]

# %%
# Normalización
YN = normalizar(Y)
YN = YN[0:10000]

# %%
plt.plot(X,Y, color='b')
plt.title('Gráfica original')
plt.xlabel('Días')
plt.ylabel('OT')
plt.grid()

# %%
plt.plot(X,YN, color='r')
plt.title('Gráfica normalizada')
plt.xlabel('Días')
plt.ylabel('OT')
plt.grid()

# %% [markdown]
# ## 2. Particion de base de datos

# %% [markdown]
# #### Procedemos a dividir la base de datos utilizando particion aleatoria de la siguiente manera
# * #### 70% entrenamiento
# * #### 30% test

# %%
corte = int(0.7*len(X)) #corte 

Xs, ys = skl.utils.shuffle(X, YN)
Xtrain = Xs[0:corte] # 70% entrenamiento
Ytrain = ys[0:corte]

Xtest = Xs[corte:] # 30% test
Ytest = ys[corte:]

plt.figure(figsize=(15,5))
plt.plot(Xtrain, Ytrain, 'or')
plt.plot(Xtest, Ytest, 'oc')
plt.plot(X, YN, '.k')
plt.legend(['datos entrenamiento', 'datos test', 'todos los datos'])
plt.grid()
plt.show()

# %% [markdown]
# ## 3. Funciones exponenciales como funciones base y parametros de modelo MAP y MLE

# %% [markdown]
# #### declaramos las funciones que se pretenden utilizar para realizar la estimacion del modelo

# %%
                                                    #Funcion exponencial base
def expo_carac(X, K):
  # Extraer caracteristicas exponenciales
  # X: N x D, vector de entradas
  # K: escalar, grado del polinomio
  # return: N x (K+1), matriz de características Phi

  X = X.flatten()
  N = X.shape[0]

  #inicializar Phi
  Phi = np.ones((N, K+1))
  U = np.linspace(0,69680,K)
  sig2 = 6000

  # Calcular matriz Phi
  for k in range(1, K+1):
      Phi[:,k] = np.exp(-(U[k-1] - X)**2/(2*sig2))
  return Phi

                                                    #Máximo a posteriori (MAP)

def inferencia_max_posterior_carac(Phi, y, sigma, alpha):
  # Phi: N x D, características de entrada
  # y: D x 1, datos de salida
  # sigma: escalar, desviación estandar del ruido
  # alpha: escalar, desviación estandar del prior sobre los parámetros
  # return: D x 1,  estimación MAP theta_map

  D = Phi.shape[1]

  # SOLUTION
  PP = Phi.T @ Phi + (sigma/alpha)**2 * np.eye(D)
  theta_map = sp.linalg.solve(PP, Phi.T @ y)

  return theta_map


def plot_prediccion(X, Y, prediccion, trainX, trainY, testX, testY):
  # Gráfica predicción

  #plt.plot(trainX, trainY, '.r', label='datos de entrenamiento')
  #plt.plot(testX, testY, '.g', label='datos de prueba')
  plt.plot(X, Y, label='función real')
  plt.plot(X, prediccion, '--', lw=2, label='predicción')
  plt.legend()

                                                #RMSE
def rmse(y, y_pred):
  # Calculo función de error
  #y = y.flatten()
  y_pred = y_pred.flatten()
  N = len(y)
  difer = (y - y_pred)**2
  return np.sqrt((1.0/N) * np.sum(difer))

                                                #MAX VEROSIMILITUD
def inferencia_max_vero_carac(Phi, y):
    # máxima verosimilitud usando caracteristicas
    # Phi: N x D, caracteristicas
    # y: N x 1, datos de salida observados
    # return: D x 1, vector de parametros estimados

    kappa = 1e-08 # jitter
    D = Phi.shape[1]

    Pt = Phi.T @ y # Phi^T*y
    PP = Phi.T @ Phi + kappa*np.eye(D) # Phi^T*Phi + kappa*I
    C = sp.linalg.cho_factor(PP)
    theta_ml = sp.linalg.cho_solve(C, Pt) # inv(Phi^T*Phi)*Phi^T*y
    return theta_ml

# %%
@interact(K = (1,500,2), sigma = (0.001, 1, 0.01), alpha=(0.001, 1, 0.01))

def RegresionMAP(K, sigma, alpha):

  Phi = expo_carac(Xtrain, K) # características datos entrenamiento

  theta_map = inferencia_max_posterior_carac(Phi, Ytrain, sigma, alpha)
  theta_ml = inferencia_max_vero_carac(Phi, Ytrain)


  # predicción sobre todos los datos (Test)
  Phi_test = expo_carac(X, K)
  y_pred_map = Phi_test @ theta_map  # Predicción usando MAP
  y_pred_ml = Phi_test @ theta_ml    # Predicción usando ML
    
    # Graficar resultados
  plt.figure(figsize=(10, 5))
  plt.plot(X, y_pred_ml, label="predicción MaxVero", color='red')
  plt.plot(X, y_pred_map, label="predicción MaxPos", color='orange')
  plt.scatter(Xtrain, Ytrain, color='blue', s=5, label="datos entrenamiento")
  plt.title(f'Predicción con k = {K}')
  plt.ylim(-0.2, 1)
  plt.legend()
  plt.grid()
  plt.show()

  # Métricas de rendimiento
  print('MSE (MAP):', mean_squared_error(YN, y_pred_map))
  print('MAE (MAP):', mean_absolute_error(YN, y_pred_map))
  print('R2 (MAP):', r2_score(YN, y_pred_map))


  # Métricas de rendimiento para MLE
  print('MSE (MLE):', mean_squared_error(YN, y_pred_ml))
  print('MAE (MLE):', mean_absolute_error(YN, y_pred_ml))
  print('R2 (MLE):', r2_score(YN, y_pred_ml))
# Out:
# interactive(children=(IntSlider(value=249, description='K', max=500, min=1, step=2), FloatSlider(value=0.491, …

# %%
import random

inicio = 8
paso = 52
total_elementos = 10

k_values = np.arange(inicio, inicio + paso * total_elementos, paso)
sigma = random.random() # Desviación estándar del ruido
print("Sigma: ", sigma)
alpha = random.random() # Desviación estándar del parámetro prior
print("alpha: ", alpha)

for i in range(len(k_values)):

  RegresionMAP(k_values[i], sigma, alpha)
# Out:
# Sigma:  0.5320945248547007
# alpha:  0.49893399806646976
# MSE (MAP): 0.029489689536253662
# MAE (MAP): 0.13480902168840586
# R2 (MAP): 0.01147094197605214
# MSE (MLE): 0.02948986595315805
# MAE (MLE): 0.13481516697947263
# R2 (MLE): 0.011465028274041056
# MSE (MAP): 0.02493214903997307
# MAE (MAP): 0.11931140585402629
# R2 (MAP): 0.16424505674438938
# MSE (MLE): 0.024930732342095824
# MAE (MLE): 0.11934127864730637
# R2 (MLE): 0.1642925461225455
# MSE (MAP): 0.01772783583862836
# MAE (MAP): 0.10339361026266179
# R2 (MAP): 0.4057421038353609
# MSE (MLE): 0.017728572810416045
# MAE (MLE): 0.10345048980964888
# R2 (MLE): 0.4057173996747362
# MSE (MAP): 0.01431066416869825
# MAE (MAP): 0.08932238821049497
# R2 (MAP): 0.5202897150548469
# MSE (MLE): 0.014305456434576954
# MAE (MLE): 0.08946638643054189
# R2 (MLE): 0.5204642844242204
# MSE (MAP): 0.00810744451307446
# MAE (MAP): 0.06900518572066842
# R2 (MAP): 0.7282289297200562
# MSE (MLE): 0.008102459991495416
# MAE (MLE): 0.06910185567298915
# R2 (MLE): 0.7283960167426297
# MSE (MAP): 0.005992707270576824
# MAE (MAP): 0.05897422244453944
# R2 (MAP): 0.7991174079362944
# MSE (MLE): 0.005988941758664297
# MAE (MLE): 0.05903753978032039
# R2 (MLE): 0.7992436323219154
# MSE (MAP): 0.004007153974900454
# MAE (MAP): 0.048699703111611724
# R2 (MAP): 0.8656754884009372
# MSE (MLE): 0.004001633110377696
# MAE (MLE): 0.048669308578326624
# R2 (MLE): 0.8658605542694487
# MSE (MAP): 0.003840079785046583
# MAE (MAP): 0.0472663578311853
# R2 (MAP): 0.8712760116385021
# MSE (MLE): 0.0038313521194890967
# MAE (MLE): 0.0472955878680706
# R2 (MLE): 0.8715685732472529
# MSE (MAP): 0.0036121025913720913
# MAE (MAP): 0.04600482897017741
# R2 (MAP): 0.8789180751548689
# MSE (MLE): 0.0036078308846065597
# MAE (MLE): 0.045939230403989624
# R2 (MLE): 0.8790612677869885
# MSE (MAP): 0.003274819525213921
# MAE (MAP): 0.044097270479163446
# R2 (MAP): 0.8902242000046025
# MSE (MLE): 0.0032625679044227356
# MAE (MLE): 0.044026667409008895
# R2 (MLE): 0.8906348887351532

# %% [markdown]
# ### Analisis
#
# * #### Segun se muesta a medida que se aumenta la cantidad de funciones exponenciales k, el modelo esta trabajando de manera efectiva por lo que ajusta bien los datos
# * #### MSE (Error cuadratico medio) siendo un valor pequeño muestra que las predicciones del modelo son muy cercanos a los valores reales
# * #### el MAE muestra que las predicciones no tienen gran desviacion
# * #### El R^2 (Coeficiente de determinacion) sugiere al aumentar K, aumenta  a valores cercanos a 1 lo que indica que el modelo tanto en predicion como en ajuste posee valores confiables

# %% [markdown]
# #### Procedemor a realizar el siguiente analisis de los resultados :

# %% [markdown]
# ## 4. Calculo de MSE

# %%
rmse_train_mle = []
rmse_test_mle = []

rmse_train_map = []
rmse_test_map = []

K_vector = []

K_max = 400

if K_max <= 100:
    cons=1
else:
    cons=9

for i in range(1, K_max,cons):
    K = i

    Phi_train = expo_carac(Xtrain, K)

    theta_mle = inferencia_max_vero_carac(Phi_train, Ytrain)
    theta_map = inferencia_max_posterior_carac(Phi_train, Ytrain,sigma,alpha)

    #Medicion Error
    y_pred_mle = Phi_train @ theta_mle # predicción
    rmse_train_mle.append(rmse(Ytrain, y_pred_mle)) # medir error
    y_pred_map = Phi_train @ theta_map # predicción
    rmse_train_map.append(rmse(Ytrain, y_pred_map)) # medir error

    # predicción sobre datos de test
    Phi_test = expo_carac(Xtest, K)

    #Medicion test
    y_pred_mle = Phi_test @ theta_mle # predicción
    rmse_test_mle.append(rmse(Ytest, y_pred_mle)) # medir error
    y_pred_map = Phi_test @ theta_map # predicción
    rmse_test_map.append(rmse(Ytest, y_pred_map)) # medir error

    K_vector.append(i)

#Maxima verosimilitud
plt.figure(figsize=(15,8))
plt.subplot(2,1,1)
plt.plot(K_vector, rmse_train_mle, '-', label='Error train')
plt.plot(K_vector, rmse_test_mle, '-', label='Error test')
plt.xticks(K_vector)
plt.title('RMSE MaxVero')
plt.ylabel('RMSE')
plt.xlabel('K')
plt.legend()
plt.tight_layout()
plt.grid()

#Maximo a posteriori
plt.subplot(2,1,2)
plt.plot(K_vector, rmse_train_map, '-', label='Error train')
plt.plot(K_vector, rmse_test_map, '-', label='Error test')
plt.xticks(K_vector)
plt.title('RMSE MaxPo')
plt.ylabel('RMSE')
plt.xlabel('K')
plt.grid()
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Analisis
# * #### ¿Cuál es el número en funciones base correspondiente al modelo con mejor capacidad de generalización?
#
#   Aunque se observa que alrrededor de los valores superiores a k = 300 se generan cambios menores, no se alcanza un valor fijo de generalizacion ya que a medida que se aumenta el numero de funciones base del modelo va obteniendo un rendimiento vs a la estimulacion
#
# * #### ¿El MSE entre las predicciónes y los datos de entrenamiento también es mínimo para ese mismo valor ?
#
# Para el metodo de maxima verosimilitud se presenta el mismo comportamiento
#
# * #### ¿Qué método (MAP o MLE) obtiene un mejor desempeño respecto a número de funciones base vs. el error?
#
# Se encuentra dificil seleccionar cual metodo obtiene mejor desempeño ya que ambos presentan un comportamiento similar entre las funciones base y el error

# %% [markdown]
# ## 5. Regresion Lineal Bayesiana

# %%
def bayesian_regression(Phi, Y, alpha, beta):
    S_0_inv = alpha * np.eye(Phi.shape[1])
    S_N_inv = S_0_inv + beta * Phi.T @ Phi
    S_N = np.linalg.inv(S_N_inv)
    m_N = beta * S_N @ Phi.T @ Y
    return m_N, S_N

# Asumiendo beta (precisión) como el inverso del ruido cuadrado
beta = 1 / sigma**2

def plot_bayesian_regression(alpha):
    # Obtener media y covarianza posterior
    m_N, S_N = bayesian_regression(Phi_train, Ytrain, alpha, beta)

    # Calcular distribución predictiva para el conjunto de prueba
    y_pred_bayes = Phi_test @ m_N
    y_std = np.sqrt(np.diag(Phi_test @ S_N @ Phi_test.T))

    # Graficar predicción Bayesiana con intervalo de confianza
    plt.figure(figsize=(10, 6))
    plt.plot(Xtest, y_pred_bayes, label=f"Predicción Bayesiana (alpha={alpha})", color="green")
    plt.fill_between(Xtest.flatten(), (y_pred_bayes - 1.96 * y_std).flatten(),
                     (y_pred_bayes + 1.96 * y_std).flatten(), color="green", alpha=0.2, label="Intervalo de confianza 95%")
    plt.scatter(Xtrain, Ytrain, color="blue", s=5, label="Datos de entrenamiento")
    plt.legend()
    plt.grid()
    plt.title(f"Regresión Bayesiana con alpha={alpha}")
    plt.show()

# Crear un slider interactivo para el parámetro alpha
interact(plot_bayesian_regression, alpha=(0.1, 100, 0.1))
# Out:
# interactive(children=(FloatSlider(value=50.00000000000001, description='alpha', min=0.1), Output()), _dom_clas…
# <function __main__.plot_bayesian_regression(alpha)>

# %% [markdown]
# ### Analisis
# * #### Al utilizar un valor de alpha pqueño (parametro que controla la confianza en el conocimiento previo sobre los valores que puede tomar el modelo) se permite mayor manejo de este donde se puede ajustar mas a los datos de entrenamiento pero genera mas incertidumbre
# * #### Siendo alpha mayor, se limita el modelo al generar mayor regulacion a la prediccion siendo asi menor la incertidumbre y se tiene el riesgo de generar un sobreajuste

# %% [markdown]
# ## Conclusiones

# %% [markdown]
# *  #### El numero de exponenciales genera cambio en la capacidad del modelo para poder ajustar los datos, es necesario intentar encontrar el equilibrio entre la flexibilidad y la regularizacion y no generar un modelo con subajuste (underfitting) ó sobreajuste (overfitting)
#
# * #### El error de entrenamiento y el error de prueba posee un comportamiento de disminucion al incrementar el numero de funciones exponenciales, lo que sugiere que el modelo mejora la capacidad de ajuste de los datos a medida que se aumentan las funciones
#
# * #### Al no tener impacto significativo el rendmiento del modelo MAP sobre MLE al utilizar una regularizacion adicional introducida el modelo no esta sobreajustado
#
# * #### Se muestra como la precision del prior afecta la complejidad (ajuste e incertidumbre) del modelo y la capacidad de generalizacion
