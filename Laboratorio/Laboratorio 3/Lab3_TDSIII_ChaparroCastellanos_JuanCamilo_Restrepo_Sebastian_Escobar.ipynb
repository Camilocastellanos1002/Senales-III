# %% [markdown]
# ![header.png](data:image/png;base64,...)

# %% [markdown]
# # Laboratorio #3 TDSIII
# # Laboratorio Segmentación de Imágenes
# ## Juan Camilo Chaparro Castellanos | Sebastian Escobar Osorio
# ## CC 1039466438 | CC 1017231742

# %% [markdown]
# ### Lectura y visualizacion de la imagen

# %% [markdown]
#  Procedemos a realizar la lectura y la visualizacion de la imagen que consta de una hoja con texto como contenido para posteriormente añadir ruido

# %%
import numpy as np
from skimage import io
import matplotlib.pyplot as plt
import skimage
import skimage.color as skic
import skimage.filters as skif
import skimage.data as skid
import skimage.util as sku

# Funciones para mostrar imágenes
def show(img):
    fig, ax = plt.subplots(1, 1, figsize=(8, 8))
    ax.set_axis_off()
    plt.show()

# %%
# Cargar la imagen
image = io.imread('imagenes/imagen_texto.png')

# Mostrar la imagen
plt.imshow(image)
plt.axis('off')
plt.show()

# %% [markdown]
#  Como puede observarse la imagen se visualiza una citacion de una audiencia publica de la secretaria de movilidad de medellin

# %% [markdown]
# ### 1. Adicion de ruido

# %% [markdown]
# * #### A) Ruido sal y pimienta

# %% [markdown]
# * #### B) Ruido Gausiano

# %% [markdown]
# ### Conclusiones
